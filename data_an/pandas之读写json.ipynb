# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
# records
js_df = pd.read_json('./data/train.json', orient='records', lines=True)
js_df
# Out:
#                                          article_link  \
# 0   https://www.huffingtonpost.com/entry/versace-b...
# 1   https://www.huffingtonpost.com/entry/roseanne-...
# 2   https://www.huffingtonpost.com/entry/versace-b...
# 3   https://www.huffingtonpost.com/entry/roseanne-...
# 4   https://www.huffingtonpost.com/entry/versace-b...
# 5   https://www.huffingtonpost.com/entry/roseanne-...
# 6   https://www.huffingtonpost.com/entry/versace-b...
# 7   https://www.huffingtonpost.com/entry/roseanne-...
# 8   https://www.huffingtonpost.com/entry/versace-b...
# 9   https://www.huffingtonpost.com/entry/roseanne-...
# 10  https://www.huffingtonpost.com/entry/versace-b...
# 11  https://www.huffingtonpost.com/entry/roseanne-...
#
#                                              headline  is_sarcastic
# 0   former versace store clerk sues over secret 'b...             0
# 1   the 'roseanne' revival catches up to our thorn...             0
# ...

# %%
# values
js_df.to_json('./data/train_values.json', orient='values')

# %%
# index
js_df.to_json('./data/train_index.json', orient='index')

# %%
# split
js_df.to_json('./data/train_split.json', orient='split')
